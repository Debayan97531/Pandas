# %% [markdown]
# <a href="https://colab.research.google.com/github/Debayan97531/Pandas/blob/main/Panda8interpolate.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #used to fill NaN values in dataframe or series
# very powerful function
#
# DataFrame.interpolate()
# Series.interpolate()

# %%
import pandas as pd

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv')
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate()#guess NaN values
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='linear')
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='time')
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
type(df.Date[1])
# Out:
# str

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',parse_dates=['Date'])

# %%
type(df.Date[0])
# Out:
# str

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#       ID             Name             Industry  Inception       Revenue  \
# Date
# Yes    1          Lamtone          IT Services       2009  $11,757,018
# Yes    2        Stripfind   Financial Services       2010  $12,329,371
# No     3  Canecorporation               Health       2012  $10,597,009
# No     4         Mattouch          IT Services       2013  $14,026,934
# No     5        Techdrill                  NaN       2009  $10,573,990
# Yes    6         Techline                  NaN       2006  $13,898,119
# Yes    7          Cityace                  NaN       2010   $9,254,614
# Yes    8   Kayelectronics               Health       2009   $9,451,943
# Yes    9          Ganzlax          IT Services       2011  $14,001,180
# Yes   10      Trantraxlax  Government Services       2011  $11,088,336
#
#                Expenses    Profit Growth
# Date
# Yes   6,482,465 Dollars   5274553    30%
# Yes     916,455 Dollars  11412916    30%
# No    7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='time')
# Out:
#       ID             Name             Industry  Inception       Revenue  \
# Date
# Yes    1          Lamtone          IT Services       2009  $11,757,018
# Yes    2        Stripfind   Financial Services       2010  $12,329,371
# No     3  Canecorporation               Health       2012  $10,597,009
# No     4         Mattouch          IT Services       2013  $14,026,934
# No     5        Techdrill                  NaN       2009  $10,573,990
# Yes    6         Techline                  NaN       2006  $13,898,119
# Yes    7          Cityace                  NaN       2010   $9,254,614
# Yes    8   Kayelectronics               Health       2009   $9,451,943
# Yes    9          Ganzlax          IT Services       2011  $14,001,180
# Yes   10      Trantraxlax  Government Services       2011  $11,088,336
#
#                Expenses    Profit Growth
# Date
# Yes   6,482,465 Dollars   5274553    30%
# Yes     916,455 Dollars  11412916    30%
# No    7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='index')
# Out:
#       ID             Name             Industry  Inception       Revenue  \
# Date
# Yes    1          Lamtone          IT Services       2009  $11,757,018
# Yes    2        Stripfind   Financial Services       2010  $12,329,371
# No     3  Canecorporation               Health       2012  $10,597,009
# No     4         Mattouch          IT Services       2013  $14,026,934
# No     5        Techdrill                  NaN       2009  $10,573,990
# Yes    6         Techline                  NaN       2006  $13,898,119
# Yes    7          Cityace                  NaN       2010   $9,254,614
# Yes    8   Kayelectronics               Health       2009   $9,451,943
# Yes    9          Ganzlax          IT Services       2011  $14,001,180
# Yes   10      Trantraxlax  Government Services       2011  $11,088,336
#
#                Expenses    Profit Growth
# Date
# Yes   6,482,465 Dollars   5274553    30%
# Yes     916,455 Dollars  11412916    30%
# No    7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='nearest')
# Out:
#       ID             Name             Industry  Inception       Revenue  \
# Date
# Yes    1          Lamtone          IT Services       2009  $11,757,018
# Yes    2        Stripfind   Financial Services       2010  $12,329,371
# No     3  Canecorporation               Health       2012  $10,597,009
# No     4         Mattouch          IT Services       2013  $14,026,934
# No     5        Techdrill                  NaN       2009  $10,573,990
# Yes    6         Techline                  NaN       2006  $13,898,119
# Yes    7          Cityace                  NaN       2010   $9,254,614
# Yes    8   Kayelectronics               Health       2009   $9,451,943
# Yes    9          Ganzlax          IT Services       2011  $14,001,180
# Yes   10      Trantraxlax  Government Services       2011  $11,088,336
#
#                Expenses    Profit Growth
# Date
# Yes   6,482,465 Dollars   5274553    30%
# Yes     916,455 Dollars  11412916    30%
# No    7,591,189 Dollars   3005820    NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',parse_dates=['Date'],index_col='Date')
df
# Out:
#       ID             Name             Industry  Inception       Revenue  \
# Date
# Yes    1          Lamtone          IT Services       2009  $11,757,018
# Yes    2        Stripfind   Financial Services       2010  $12,329,371
# No     3  Canecorporation               Health       2012  $10,597,009
# No     4         Mattouch          IT Services       2013  $14,026,934
# No     5        Techdrill                  NaN       2009  $10,573,990
# Yes    6         Techline                  NaN       2006  $13,898,119
# Yes    7          Cityace                  NaN       2010   $9,254,614
# Yes    8   Kayelectronics               Health       2009   $9,451,943
# Yes    9          Ganzlax          IT Services       2011  $14,001,180
# Yes   10      Trantraxlax  Government Services       2011  $11,088,336
#
#                Expenses    Profit Growth
# Date
# Yes   6,482,465 Dollars   5274553    30%
# Yes     916,455 Dollars  11412916    30%
# No    7,591,189 Dollars   3005820    NaN
# ...

# %%
df.interpolate(method='spline',order=2)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-21-4fd5b971e18e> in <module>
# ----> 1 df.interpolate(method='spline',order=2)
#
# /usr/local/lib/python3.7/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/frame.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
#   10718             limit_area,
#   10719             downcast,
# > 10720             **kwargs,
#   10721         )
#   10722
#
# /usr/local/lib/python3.7/dist-packages/pandas/core/generic.py in interpolate(self, method, axis, limit, inplace, limit_direction, limit_area, downcast, **kwargs)
# ...
