# %% [markdown]
# <a href="https://colab.research.google.com/github/Debayan97531/Pandas/blob/main/panda5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**missing values**

# %%
import pandas as pd

# %% [markdown]
# **na_values,keep_default_na,na_filter,isnull,not null,dropna(axis,how,thresh,inplace)**

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv')
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',na_values=['not available','No'])
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3  NaN  Canecorporation               Health       2012  $10,597,009
# 3   4  NaN         Mattouch          IT Services       2013  $14,026,934
# 4   5  NaN        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    NaN
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',na_values={'Industry':'Health'})
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation                  NaN       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',keep_default_na=False)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline                 #N/A       2006  $13,898,119
# 6   7  Yes          Cityace                            2010   $9,254,614
# 7   8  Yes   Kayelectronics                            2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916           null
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',keep_default_na=True)
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics                  NaN       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit         Growth
# 0  6,482,465 Dollars   5274553            30%
# 1    916,455 Dollars  11412916            NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv')
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline               Health       2006  $13,898,119
# 6   7  Yes          Cityace               Health       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    30%
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv',na_filter=False)##for boosting if there is no NAN
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill               Health       2009  $10,573,990
# 5   6  Yes         Techline               Health       2006  $13,898,119
# 6   7  Yes          Cityace               Health       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    30%
# ...

# %%
df.isnull()
# Out:
#       ID   Date   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False  False     False      False    False     False   False   False
# 1  False  False  False     False      False    False     False   False   False
# 2  False  False  False     False      False    False     False   False   False
# 3  False  False  False     False      False    False     False   False   False
# 4  False  False  False     False      False    False     False   False   False
# 5  False  False  False     False      False    False     False   False   False
# 6  False  False  False     False      False    False     False   False   False
# 7  False  False  False     False      False    False     False   False   False
# 8  False  False  False     False      False    False     False   False   False
# 9  False  False  False     False      False    False     False   False   False

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv')
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df.isnull()
# Out:
#       ID   Date   Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  False  False  False     False      False    False     False   False   False
# 1  False  False  False     False      False    False     False   False   False
# 2  False  False  False     False      False    False     False   False    True
# 3  False  False  False     False      False    False     False   False    True
# 4  False  False  False      True      False    False     False   False   False
# 5  False  False  False      True      False    False     False   False   False
# 6  False  False  False      True      False    False     False   False   False
# 7  False  False  False     False      False    False     False   False   False
# 8  False  False  False     False      False    False      True   False   False
# 9  False  False  False     False      False    False     False   False   False

# %%
df.isnull().sum()
# Out:
# ID           0
# Date         0
# Name         0
# Industry     3
# Inception    0
# Revenue      0
# Expenses     1
# Profit       0
# Growth       2
# dtype: int64

# %%
df.isnull().sum().sum()
# Out:
# 6

# %%
df.notnull()
# Out:
#      ID  Date  Name  Industry  Inception  Revenue  Expenses  Profit  Growth
# 0  True  True  True      True       True     True      True    True    True
# 1  True  True  True      True       True     True      True    True    True
# 2  True  True  True      True       True     True      True    True   False
# 3  True  True  True      True       True     True      True    True   False
# 4  True  True  True     False       True     True      True    True    True
# 5  True  True  True     False       True     True      True    True    True
# 6  True  True  True     False       True     True      True    True    True
# 7  True  True  True      True       True     True      True    True    True
# 8  True  True  True      True       True     True     False    True    True
# 9  True  True  True      True       True     True      True    True    True

# %%
df.notnull().sum()
# Out:
# ID           10
# Date         10
# Name         10
# Industry      7
# Inception    10
# Revenue      10
# Expenses      9
# Profit       10
# Growth        8
# dtype: int64

# %%
df.notnull().sum().sum()
# Out:
# 84

# %%
#Series
import numpy as np
sr=pd.Series([1,2,3,np.nan,4,np.NAN])
sr
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# 4    4.0
# 5    NaN
# dtype: float64

# %%
sr.isnull()
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# 4    False
# 5     True
# dtype: bool

# %%
sr.isnull().sum()
# Out:
# 2

# %%
df.dropna()
# Out:
#    ID Date            Name             Industry  Inception       Revenue  \
# 0   1  Yes         Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes       Stripfind   Financial Services       2010  $12,329,371
# 7   8  Yes  Kayelectronics               Health       2009   $9,451,943
# 9  10  Yes     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 7  3,878,113 Dollars   5573830     4%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.dropna(axis=1)
# Out:
#    ID Date             Name  Inception       Revenue    Profit
# 0   1  Yes          Lamtone       2009  $11,757,018    5274553
# 1   2  Yes        Stripfind       2010  $12,329,371   11412916
# 2   3   No  Canecorporation       2012  $10,597,009    3005820
# 3   4   No         Mattouch       2013  $14,026,934    6597557
# 4   5   No        Techdrill       2009  $10,573,990    3138627
# 5   6  Yes         Techline       2006  $13,898,119    8427816
# 6   7  Yes          Cityace       2010   $9,254,614    3005116
# 7   8  Yes   Kayelectronics       2009   $9,451,943    5573830
# 8   9  Yes          Ganzlax       2011  $14,001,180   11901180
# 9  10  Yes      Trantraxlax       2011  $11,088,336    5453060

# %%
df.dropna(how='any')#same as dropna
# Out:
#    ID Date            Name             Industry  Inception       Revenue  \
# 0   1  Yes         Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes       Stripfind   Financial Services       2010  $12,329,371
# 7   8  Yes  Kayelectronics               Health       2009   $9,451,943
# 9  10  Yes     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 7  3,878,113 Dollars   5573830     4%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.dropna(axis=1,how='any')#like only dropna
# Out:
#    ID Date             Name  Inception       Revenue    Profit
# 0   1  Yes          Lamtone       2009  $11,757,018    5274553
# 1   2  Yes        Stripfind       2010  $12,329,371   11412916
# 2   3   No  Canecorporation       2012  $10,597,009    3005820
# 3   4   No         Mattouch       2013  $14,026,934    6597557
# 4   5   No        Techdrill       2009  $10,573,990    3138627
# 5   6  Yes         Techline       2006  $13,898,119    8427816
# 6   7  Yes          Cityace       2010   $9,254,614    3005116
# 7   8  Yes   Kayelectronics       2009   $9,451,943    5573830
# 8   9  Yes          Ganzlax       2011  $14,001,180   11901180
# 9  10  Yes      Trantraxlax       2011  $11,088,336    5453060

# %%
df.dropna(how='all')
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df=pd.read_csv('/content/Fortune_10 (2).csv')
df.dropna(thresh=1)#min 1NAN in row
df
# Out:
#    ID Date             Name             Industry  Inception       Revenue  \
# 0   1  Yes          Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes        Stripfind   Financial Services       2010  $12,329,371
# 2   3   No  Canecorporation               Health       2012  $10,597,009
# 3   4   No         Mattouch          IT Services       2013  $14,026,934
# 4   5   No        Techdrill                  NaN       2009  $10,573,990
# 5   6  Yes         Techline                  NaN       2006  $13,898,119
# 6   7  Yes          Cityace                  NaN       2010   $9,254,614
# 7   8  Yes   Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes          Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes      Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 2  7,591,189 Dollars   3005820    NaN
# ...

# %%
df.dropna(subset=['ID','Industry','Growth'])#for column
# Out:
#    ID Date            Name             Industry  Inception       Revenue  \
# 0   1  Yes         Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes       Stripfind   Financial Services       2010  $12,329,371
# 7   8  Yes  Kayelectronics               Health       2009   $9,451,943
# 8   9  Yes         Ganzlax          IT Services       2011  $14,001,180
# 9  10  Yes     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 7  3,878,113 Dollars   5573830     4%
# 8                NaN  11901180    18%
# 9  5,635,276 Dollars   5453060     7%

# %%
df.dropna(inplace=True)
df
# Out:
#    ID Date            Name             Industry  Inception       Revenue  \
# 0   1  Yes         Lamtone          IT Services       2009  $11,757,018
# 1   2  Yes       Stripfind   Financial Services       2010  $12,329,371
# 7   8  Yes  Kayelectronics               Health       2009   $9,451,943
# 9  10  Yes     Trantraxlax  Government Services       2011  $11,088,336
#
#             Expenses    Profit Growth
# 0  6,482,465 Dollars   5274553    30%
# 1    916,455 Dollars  11412916    30%
# 7  3,878,113 Dollars   5573830     4%
# 9  5,635,276 Dollars   5453060     7%
